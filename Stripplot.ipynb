# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("character-deaths.csv")
sns.stripplot(x='Death Year',y='Death Chapter',data=df,size=4,jitter=True)
plt.ylabel('Death Chapter')
plt.show()
