# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("character-deaths.csv")
sns.swarmplot(x='Death Year',y='Death Chapter',data=df,hue='Gender')
plt.ylabel('Death Chapter')
plt.show()
